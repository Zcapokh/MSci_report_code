# %%
# !pip install cdflib
# !pip install pymap3d

# %%
import cdflib
import pymap3d
import numpy as np
import pandas as np
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/gdrive')

# %%
##################################
## GRACE-A simulation
##################################
graceA1 = cdflib.CDF('/content/gdrive/MyDrive/msci_satellite_data/...')
graceA2 = cdflib.CDF()
nodrag_graceA = pd.DataFrame(np.loadtxt('output_050324_nodrag_graceA.txt'))
ussa_graceA =
truth_graceA =
exp3_graceA =

# %%
def plot_orbits(realdata23, realdata24, nodrag, ussa, truth, exp3):
  ''''''
  fig = plt.figure(figsize=(9,9))
  ax = plt.axes(projection='3d')
  plt.plot(nodrag.values[7], nodrag_graceA.values[8], nodrag_graceA.values[9], label='no drag')
  plt.plot(ussa_graceA.values[7],ussa_graceA.values[8],ussa_graceA.values[9],label='USSA76')
  #
  #

  # Calculate the absolute spatial difference
  r_nodrag = (nodrag)
