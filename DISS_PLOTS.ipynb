# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ds = xr.open_dataset('/content/gdrive/MyDrive/msci_satellite_data/matsuo_tiegcm_ose/tiegcm_s_ensmean.nc.01')
cosmic = xr.open_dataset('/content/gdrive/MyDrive/msci_satellite_data/cosmic/.ionPrf_postProc_2008_175/23sat1/ionPrf_C001.2008.175.01.34.G03_2021.0390_nc')

# %%
plt.figure(figsize=(7,6))
plt.plot(cosmic.GEO_lon.values[75], cosmic.GEO_lat.values[75], 'o', color='tab:blue', label='Electron density / cm-3')
ds.lon.values[34]
ds.lon.values[38]
ds.lat.values[10]
x = [ds.lon.values[34], ds.lon.values[34], ds.lon.values[35], ds.lon.values[35], ds.lon.values[36], ds.lon.values[36]]
y = [ds.lat.values[10], ds.lat.values[11], ds.lat.values[10], ds.lat.values[11], ds.lat.values[10], ds.lat.values[11]]
plt.plot(x, y, 'go', label='TIEGCM grid')
plt.title('Horizontal grid sliced at altitude 275km')
plt.xlabel('Longitude / degrees')
plt.ylabel('Latitude / degrees')
plt.legend()
plt.grid(True)
plt.show()

# %%
fig = plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
z0 = np.ones((6,), dtype=int) * ds.ZG.values[1, 0, 1, 1]/100000
z1 = np.ones((6,), dtype=int) * ds.ZG.values[1, 3, 1, 1]/100000
z2 = np.ones((6,), dtype=int) * ds.ZG.values[1, 6, 1, 1]/100000
z3 = np.ones((6,), dtype=int) * ds.ZG.values[1, 9, 1, 1]/100000
z4 = np.ones((6,), dtype=int) * ds.ZG.values[1, 12, 1, 1]/100000
z5 = np.ones((6,), dtype=int) * ds.ZG.values[1, 15, 1, 1]/100000
z6 = np.ones((6,), dtype=int) * ds.ZG.values[1, 18, 1, 1]/100000
z7 = np.ones((6,), dtype=int) * ds.ZG.values[1, 21, 1, 1]/100000
z8 = np.ones((6,), dtype=int) * ds.ZG.values[1, 24, 1, 1]/100000
z9 = np.ones((6,), dtype=int) * ds.ZG.values[1, 27, 1, 1]/100000
ax.plot(cosmic.GEO_lon.values[:-200], cosmic.GEO_lat.values[:-200], cosmic.MSL_alt.values[:-200], color='tab:blue', label='RO EDP')
ax.plot(x, y, z0, 'go', label = 'TIEGCM grid')
ax.plot(x, y, z3, 'go')
ax.plot(x, y, z4, 'go')
ax.plot(x, y, z5, 'go')
ax.plot(x, y, z6, 'go')
ax.plot(x, y, z7, 'go')
ax.plot(x, y, z8, 'go')
ax.plot(x, y, z9, 'go')
ax.set_xlabel('Longitude / degrees')
ax.set_ylabel('Latitude / degrees')
ax.set_zlabel('Altitude / km')
ax.set_title('Path of an electron density profile through the TIEGCM grid')
plt.legend()
plt.show()

# %%
z6
# Out:
# array([275.78814, 275.78814, 275.78814, 275.78814, 275.78814, 275.78814])

# %%
cosmic.MSL_alt.values[75]
array = np.array

# %%
# C005 12
ose12 = [array(42148.48400083), array(62532.90973128), array(83626.19107524), array(93982.73327221), array(96440.27492558), array(99285.02969899), array(108820.96402525), array(126723.97568638), array(150892.25630029), array(176307.30301859), array(196468.47109849), array(211554.04213686), array(220254.42441537), array(228104.12884267), array(255990.52922696), array(326136.22415641), array(451178.85568124), array(605500.06728718), array(717535.18482271), array(724303.75444907), array(639543.8186569), array(513405.81111921), array(385109.10862514), array(281527.8044212), array(208276.21025397), array(158557.44115408), array(124257.09799642), array(99930.55841356), array(81469.56426248)]
znasa4 = [95.96648, 98.42017, 100.7976, 103.48329, 107.02777, 111.31416, 116.72115, 123.50815, 131.61175, 140.99325, 151.53455, 163.23903, 176.06442, 190.1093, 205.38588, 221.8812, 239.5482, 258.3035, 277.96076, 298.3388, 319.4802, 341.33016, 363.88392, 387.20528, 411.3212, 436.17936, 462.87768, 492.43952, 522.00136]

# %%
# C005 16
ose20 = [array(2101.57638925), array(2759.00777481), array(3277.21819524), array(3340.75819525), array(3074.37288402), array(2635.72778735), array(2222.32105405), array(1974.98580168), array(1995.41226073), array(2254.58437625), array(2559.76434434), array(2718.91258086), array(2707.55882372), array(2729.09891159), array(3107.05878681), array(4715.70685802), array(10086.86484082), array(24658.7769414), array(58592.65235879), array(113812.43471759), array(169565.50196957), array(203128.94419617), array(207333.80277881), array(187118.20983095), array(154534.08886269), array(121501.31716316), array(95867.32471891), array(76901.22581963), array(62266.99543381)]
zose20 = [96.11937, 98.82587, 101.56755, 104.34286, 107.44659, 111.34106, 116.36283, 122.70182, 130.55027, 139.84353, 150.53545, 162.63699, 175.94322, 189.68082, 204.38968, 220.03288, 236.50888, 253.3773, 270.764, 288.73142, 306.9916, 325.37328, 343.9274, 362.60224, 381.36048, 400.1756, 419.02912, 437.9042, 456.7556]
cosmic20 = xr.open_dataset('/content/gdrive/MyDrive/msci_satellite_data/cosmic/.ionPrf_postProc_2008_175/23sat5/ionPrf_C005.2008.175.16.37.G09_2021.0390_nc')
nasa20 = [array(2017.27839385), array(2712.18250317), array(3298.71398579), array(3383.24503022), array(3081.37519962), array(2635.9244185), array(2266.97473884), array(2135.7785318), array(2391.35750416), array(3105.8184007), array(4222.04951933), array(5652.57220021), array(7432.36908302), array(9990.53009357), array(14894.00676497), array(26821.91981533), array(56580.71205298), array(117910.87669899), array(209505.74432682), array(300682.65428044), array(356828.12559549), array(365907.1661171), array(338797.10958554), array(290128.75950212), array(229441.62466237), array(172984.79955911), array(130440.11951249), array(100374.95788316), array(78309.23807728)]
znasa20 = [96.07038, 98.55693, 101.09675, 103.84038, 106.97326, 110.8765, 115.98353, 122.519, 130.60574, 140.00923, 150.59655, 162.10621, 174.55054, 187.9261, 202.4477, 218.1262, 234.91454, 252.65004, 271.15212, 290.42782, 310.3472, 330.89948, 352.0708, 373.87396, 396.43384, 420.03564, 445.111, 472.40808, 498.6658]

# %%
fig, axs = plt.subplots(1,3,figsize=(15,7))
axs[1].plot(cosmic12.ELEC_dens.values, cosmic12.MSL_alt.values, label='COSMIC-1 satellite 5 at 12:30:28')
axs[1].plot(nasa12, znasa12, label='Normal TIEGCM')
axs[1].plot(ose12, zose12, label='DA TIEGCM')
axs[1].set_ylim(90,550)
axs[1].set_xlabel('Electron density / $cm^{-3}$')
axs[1].set_ylabel('Altitude / km')
axs[1].set_title('Interpolated electron density profiles at UT12')
axs[1].legend()

axs[0].plot(cosmic4.ELEC_dens.values, cosmic4.MSL_alt.values, label='COSMIC-1 satellite 5 at 04:05:24')
axs[0].plot(nasa4, znasa4, label='Normal TIEGCM')
axs[0].plot(ose4, zose4, label='DA TIEGCM')
axs[0].set_ylim(90,550)
axs[0].set_xlabel('Electron density / $cm^{-3}$')
axs[0].set_ylabel('Altitude / km')
axs[0].set_title('Interpolated electron density profiles at UT04')
axs[0].legend()

t = [95.8114, 98.63991, 101.23733, 104.05522, 107.60296, 111.99324, 117.63658, 124.78892, 133.46096, 143.55535, 154.71542, 166.52805, 179.3988, 193.24096, 208.02684, 223.82866, 240.5952, 257.86474, 275.81414, 294.32054, 313.26508, 332.54262, 351.8642, 371.34624, 390.95036, 410.6396, 430.38708, 450.17384, 469.9868]
dt = xr.open_dataset('/content/gdrive/MyDrive/msci_satellite_data/cosmic/.ionPrf_postProc_2008_175/23sat2/ionPrf_C002.2008.175.03.56.G14_2021.0390_nc')

# %%
fig, axs = plt.subplots(1,3,figsize=(15,7))
axs[0].plot(df.ELEC_dens.values[20:], df.MSL_alt.values[20:], label='COSMIC-1 satellite 2 at 03:52:56')
axs[0].plot(first, f, 'g', label='DA TIEGCM')
axs[0].set_ylim(90,550)
axs[0].set_xlabel('Electron density / $cm^{-3}$')
axs[0].set_ylabel('Altitude / km')
axs[0].set_title('Interpolated electron density profiles at UT03')
axs[0].set_xlim(-10,None)
axs[0].legend()

axs[1].plot(ds.ELEC_dens.values, ds.MSL_alt.values, label='COSMIC-1 satellite 2 at 03:53:50')
axs[1].plot(second, s, 'g', label='DA TIEGCM')
axs[1].set_ylim(90,550)
axs[1].set_xlabel('Electron density / $cm^{-3}$')
axs[1].set_ylabel('Altitude / km')
axs[1].set_title('Interpolated electron density profiles at UT03')
axs[1].legend()

axs[2].plot(dt.ELEC_dens.values, dt.MSL_alt.values, label='COSMIC-1 satellite 2 at 03:55:18')
axs[2].plot(third, t, 'g', label='DA TIEGCM')
axs[2].set_ylim(90,550)
axs[2].set_xlabel('Electron density / $cm^{-3}$')
axs[2].set_ylabel('Altitude / km')
axs[2].set_title('Interpolated electron density profiles at UT03')
axs[2].legend()

# %%
#!pip install pymap3d
import pymap3d
import datetime
bx = np.array([-5151.070772,  1510.962319,  3760.529063, -4941.730922,
         698.380167,  4288.016376, -4607.629831,  -131.844981,
        4706.68318 , -4157.197563,  -958.696612,  5005.90102 ,
       -3601.794121, -1761.266934,  5178.076161, -2955.427152,
       -2519.282783,  5218.844256, -2234.403913, -3213.614146,
        5127.182557, -1456.925373, -3826.752731,  4905.436546,
        -642.631449, -4343.249405,  4559.2597  ,   187.891698,
       -4750.099627,  4097.46785 ,  1013.630761, -5037.06767 ,
        3531.811623,  1813.677464, -5196.941517,  2876.673108,
        2567.760488, -5225.712058,  2148.694813,  3256.762862,
       -5122.672101,  1366.351038,  3863.211328, -4890.432555,
         549.473458,  4371.723742, -4534.855719,  -281.255803,
        4769.402869, -4064.90762 , -1104.829905,  5046.166149,
       -3492.433295, -1900.448584,  5195.002772, -2831.860921,
       -2648.041017,  5212.151808, -2099.841958, -3328.768054,
        5097.197011, -1314.836037, -3925.491534,  4853.076202,
        -496.649862, -4423.200017,  4486.005141,   334.057273,
       -4809.382012,  4005.317239,  1156.294148, -5074.33575 ,
        3423.223708])
by = np.array([  629.921878, -6265.768503,  5048.457578,  1684.476524,
       -6578.359518,  4277.122182,  2696.442639, -6724.368971,
        3397.309965,  3640.270111, -6700.200055,  2431.333092,
        4492.119922, -6506.559898,  1403.696564,  5230.46117 ,
       -6148.433052,   340.474404,  5836.612628, -5634.948601,
        -731.355088,  6295.215393, -4979.144789, -1784.598165,
        6594.624961, -4197.636826, -2792.540644,  6727.211887,
       -3310.196409, -3729.630935,  6689.562666, -2339.252863,
       -4572.132856,  6482.574269, -1309.328414, -5298.730843,
        6111.438819,  -246.421375, -5891.071397,  5585.517668,
         822.647165, -6334.226497,  4918.107222,  1870.907148,
       -6617.066687,  4126.102472,  2871.915984, -6732.534766,
        3229.567153,  3800.421056, -6677.814203,  2251.222094,
        4632.992373, -6454.389277,  1215.865411,  5348.609391,
       -6067.997013,   149.740004,  5929.188612, -5528.473422,
        -920.135385,  6360.039059, -4849.499125, -1966.654629,
        6630.235007, -4048.250966, -2963.312906,  6732.896629,
       -3144.968317, -3884.883585,  6665.370689, -2162.444548,
       -4708.058717])
bz = np.array([-4353.25485 ,  2057.461152,  2471.066186, -4314.980451,
        1423.612853,  3007.577625, -4167.761094,   753.750315,
        3467.75513 , -3915.309492,    64.842884,  3839.919863,
       -3563.987804,  -625.677955,  4114.628334, -3122.650196,
       -1300.357995,  4284.913866, -2602.423798, -1942.159004,
        4346.465009, -2016.432872, -2534.885751,  4297.736115,
       -1379.472116, -3063.591467,  4139.986762,  -707.636721,
       -3514.951581,  3877.248801,   -17.917615, -3877.596846,
        3516.22157 ,   672.227862, -4142.397409,  3066.098014,
        1345.319266, -4302.690747,  2538.326381,  1984.298498,
       -4354.447714,  1946.314081,  2572.96591 , -4296.372445,
        1305.081901,  3096.394662, -4129.933718,   630.878521,
        3541.312529, -3859.327345,   -59.234042,  3896.440983,
       -3491.370821,  -747.813385,  4152.782686, -3035.333122,
       -1417.476495,  4303.850246, -2502.703927, -2051.335879,
        4345.830568, -1906.907867, -2633.421324,  4277.680963,
       -1262.97005 , -3149.07752 ,  4101.154436,  -587.142043,
       -3585.329279,  3820.75366 ,   103.506512, -3931.20369 ,
        3443.614508])
nlatitude = []
nlongitude = []
naltitude = []
for i in np.arange(0,73,1):
    delta = datetime.timedelta(seconds=int(i*1800))
    lat, lon, alt = pymap3d.ecef.eci2geodetic(bx[i]*1000, by[i]*1000, bz[i]*1000, datetime.datetime(2018, 6, 12, 9, 50, 0)+delta)
    nlatitude.append(lat)
    nlongitude.append(lon)
    naltitude.append(alt)

# %%
plt.plot(nlongitude, nlatitude)
#plt.plot(np.array(naltitude)/1000)

# %%
baltitude
# Out:
# [399976.3106775779,
#  377459.0858064749,
#  373367.30470223073,
#  398650.22803358175,
#  377957.90325887996,
#  374488.7198765165,
#  396669.694807921,
#  378924.0248989995,
#  375725.24285623955,
#  394139.870578031,
#  380372.0208965351,
#  376943.7734036093,
#  391199.4681952094,
#  382274.80814984237,
#  378025.7405811477,
#  388011.15253576025,
#  384564.088193383,
#  378876.9965913065,
#  384750.34797526477,
#  387134.3517546374,
#  379435.3482209005,
#  381592.86603129,
#  389850.074936173,
#  379675.30007444543,
#  378702.4666638861,
#  392555.38511618687,
#  379609.5719278755,
#  376219.262240961,
#  395085.45169342693,
#  379287.4338202297,
#  374250.06847892737,
#  397278.68404172227,
#  378789.8741558805,
#  372861.37521271466,
#  398988.7019380157,
#  378222.0991737416,
#  372075.65266803536,
#  400095.2149165957,
#  377703.8019793744,
#  371871.2342302817,
#  400513.0065350943,
#  377358.05371553026,
#  372185.8560289066,
#  400198.4541450825,
#  377299.6798695743,
# ...
